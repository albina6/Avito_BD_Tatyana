# %% [markdown]
# ## Создадим таблицу Должности (POSTS) используя интерфейс.
# ![image.png](attachment:5b4be585-c659-4efc-9edd-061adc17d8cb.png)

# %% [markdown]
# ## Создадим и другие таблицы, отобразим создание таблицы ЗАКАЗЫ (Orders) используя SQL - запрос.
# ````sql
# CREATE TABLE ORDERS
# (
# O_ID INT IDENTITY(1,1) NOT NULL,
# O_COMPANY INT NOT NULL,
# O_DATE DATE NOT NULL,
# O_READY DATE,
# PRIMARY KEY(O_ID),
# FOREIGN KEY (O_COMPANY) REFERENCES Customers(C_ID)
# );
# ````

# %% [markdown]
# ### Посмотрим на диаграмму ДБ, на данном этапе она выглядит следующим образом:
# ![image.png](attachment:3c21d9dc-ca1e-4194-9cae-3ee1d878fcca.png)

# %% [markdown]
# ![image.png](attachment:cde09e41-2fa3-440b-9b37-a69ec5759a67.png)

# %% [markdown]
# ### После создания ограничений, диаграмма выглядит следующим образом
# ![image.png](attachment:45733711-3b11-4566-9de8-177f841501ee.png)

# %% [markdown]
# ### Заполним таблицу я ЗАКАЗЧИКИ (Customers) с помощью SQL-запроса
#
# ````sql
# INSERT INTO CUSTOMERS VALUES
# ('Ефремов', 'г. Уфа, ул. Кирова'),
# ('Одинцов', 'г. Казань, ул. Гагарина'),
# ('Карпов', 'г. Уфа, ул. Ленина'),
# ('Литвинова', 'г. Уфа, ул. Первомайская'),
# ('Низаева', 'г.Москва, ул. Пушкина');
#
# ````

# %% [markdown]
# ![image.png](attachment:5be6f7d8-f159-4a02-800f-a2591d9ea866.png)

# %% [markdown]
# ## Пример. Удалить одну строку из таблицы ЗАКАЗЧИКИ (Customers) для которой справедливо условие: адрес не начинается с «г. Уфа»
#
# ````sql
# DELETE TOP (1)
#   FROM CUSTOMERS
#  WHERE C_ADDR NOT LIKE 'г. Уфа%';
#
# ````

# %% [markdown]
# ![image.png](attachment:8a05f386-08fb-4bd9-8153-106861b292b8.png)

# %% [markdown]
# ![image.png](attachment:31694324-2384-4fb2-8bdc-24dce0a9b260.png)

# %% [markdown]
# ### Заполним таблицу ДОЛЖНОСТИ (Posts) с помощью SQL-запроса

# %% [markdown]
# ```sql
# INSERT INTO PoPOSTSsts VALUES
# ('Менеджер', 15000),
# ('Редактор', 20000),
# ('Программист', 50000),
# ('Главный редактор', 150000),
# ('Несуществующая должность', -16000);
#
# ```

# %% [markdown]
# #### Результат исполнения кода
# ![image.png](attachment:2a817c30-1f28-43f6-af25-e8e68ce63f69.png)

# %% [markdown]
# ![image.png](attachment:df706136-f228-401b-bfaa-be0c44c81fbd.png)

# %% [markdown]
# ## Пример: Удалить должность из таблицы Posts, у которой зарплата < 0
#
# ````sql
# DELETE FROM POSTS
#  WHERE P_SAL < 0;
#
# ````
# .

# %% [markdown]
# ![image.png](attachment:7dd0ede8-43d4-4c9d-b79f-f18a6e28d706.png)

# %% [markdown]
# ![image.png](attachment:7c9837ad-4246-4e72-b38f-75d392ec3d2f.png)

# %% [markdown]
# ## Дополним таблицу должностей
#
# ````sql
# INSERT INTO POSTS VALUES
# ('Администратор', 20000),
# ('Уборщик', 15000),
# ('Директор', 60000),
# ('Стажер ', 10000);
#
# ````
#
# ![image.png](attachment:7cab200c-d60e-4690-be9a-667ba8b5816d.png)

# %% [markdown]
# ## Пример: Удалим записи из таблицы Posts, у которых значение поля P_ID будет между 5 и 8.
#
# ````sql
# DELETE FROM POSTS
#  WHERE P_ID BETWEEN 5 AND 8;
#
# ````

# %% [markdown]
# ![image.png](attachment:36fe60ea-7bd0-49fb-8689-ed35cd3d886a.png)

# %% [markdown]
# # 3.1.3. Изменение данных в таблице

# %% [markdown]
# ## Пример: В таблице POSTS переименовать «Менеджера» в «Редактора» название
#
# ````sql
# UPDATE POSTS
#  SET P_POST = 'Редактор'
# WHERE P_POST = 'Менеджер';
#
# ````

# %% [markdown]
# ![image.png](attachment:b1e79245-c431-47eb-9d49-d4060e7ab9d3.png)

# %% [markdown]
# ## Заполним таблицу КОМНАТЫ (Rooms)
#
# ````sql
# INSERT INTO ROOMS VALUES
# (10, '20-50-74'),
# (3, '9578423654'),
# (13, '055487'),
# (14, '84-48-14');
#
# ````

# %% [markdown]
# ![image.png](attachment:3eea40a8-6fb1-4707-a01d-bf2d4dc5c931.png)

# %% [markdown]
# ## Заполним таблицу СОТРУДНИКИ (Employees)
# ### E_SEX (0 - Men, 1 - Women)

# %% [markdown]
# ```sql
# INSERT INTO EMPLOYEES VALUES
# ('Бенгальский', 'Жорж', '1974-04-13', 0, 2, 3, '9578423654', '124895137845', '8457 595268', 'г. Москва, ул.', '1988-04-05' , NULL),
# ('Босой', 'Никанор', '2001-01-30', 0, 9, 3, '9578423654', '175846024846', '4851 204526', 'г. Москва, ул.', '2008-04-5', NULL),
# ('Лиходеев', 'Степан', '1995-06-18', 0, 1, 13, '055487', '843801642278', '4851 829473', 'г. Уфа, ул.', '2010-12-3', 'г. Казань, ул.'),
# ('Семплеяров', 'Аркадий', '1955-08-14', 0, 3, 10, '20-50-74', '170033481476', '8941 589615', 'г. Уфа, ул.', '2013-09-13', NULL),
# ('Соков', 'Андрей', '1995-07-09', 0, 2, 3, '9578423654', '107958451511', '1574 854612', 'г. Казань, ул.', '2017-4-12', 'г. Казань, ул.'),
# ('Кадырова', 'Алсу', '2000-05-06', 1, 1, 14, '84-48-14 ', '480277158940', '8554 256792', 'г. Казань, ул.', '2019-01-4', 'г. Москва, ул.');
#
# ```

# %% [markdown]
# ![image.png](attachment:a1837617-98f1-4ea3-b148-686bdbcf92f0.png)

# %% [markdown]
# ## Пример: Увеличить значение даты рождения у всех строк на 1 в таблице СОТРУДНИКИ (Employees)
#
# ````sql
# UPDATE EMPLOYEES
#    SET E_BORN = DATEADD(day, 1, E_BORN);
#
#
# ````

# %% [markdown]
# # Заполним остальные таблицы БД

# %% [markdown]
# ````sql
#
# INSERT INTO CUSTOMERS VALUES
# ('Воланд', 'г. Москва, ул. Садовая'),
# ('Коровьев', 'г. Москва, ул. Победы'),
# ('Магарита', 'г. Москва, ул. Юбилейная'),
# ('Бегемот', 'г. Уфа, ул. Карла Маркса');
# ````

# %% [markdown]
# ![image.png](attachment:0efb7c1c-bceb-421d-abc8-09a6d311806e.png)

# %% [markdown]
# ````sql
#
# INSERT INTO AUTHORS (A_FNAME, A_LNAME, A_INN, A_PASSP, A_PDATE, A_ORG, A_ADDR, A_TEL)VALUES
# ('Булгаков', 'Михаил', '178495482355', '1475 148527', '1930-03-10', 'г. Москва, МВД по ', 'г. Москва, ул. ', '142548'),
# ('Гоголь', 'Николай', '1792004584', '1424 364572', '2008-12-03', 'МВД по РБ', 'г. Москва, ул. ', '15-48-84'),
# ('Пушкин', 'Александр', '845744571941', '1447 551002', '2013-03-14', 'МВД по МО', 'г. Уфа, ул. ', '948-785-4874'),
# ('Достоевский', 'Федор', '486140355671', '2205 128845', '2014-10-12', 'МВД по МО', 'г. Уфа, ул. ', '987-484-7850'),
# ('Донцова', 'Дарья', '175229443378', '1240 748758', '2003-12-01', 'МВД по МО', 'г. Москва, ул. ', '74-84-79');
#
# ````

# %% [markdown]
# ![image.png](attachment:5a324848-e8a1-454a-951a-acc5405a2c7b.png)

# %% [markdown]
# ````sql
#
# INSERT INTO BOOKS (B_DATE, B_MAN, B_TITLE, B_PRICE, B_ADVANCE, B_FEE, B_PUBL, B_CIRCUL, B_EDIT, B_REST) VALUES
# ('2001-12-04', 3, 'Мастер и Маргарита', 1200, 500, 200, '2002-02-13', 1100, 4, 1100 ),
# ('2010-04-22', 4, 'Преступление и наказание', 2500, 1000, 500, '2010-10-05', 2000, 7, 2000),
# ('2005-10-01', 3, 'Мертвые души', 1700, 600, 450, '2006-02-01', 950, 5, 950),
# ('2007-06-18', 7, 'Евгений Онегин', 1100, 300, 501, '2007-11-20', 2500, 6, 2500),
# ('2008-05-03', 8, 'Амулет добра', 500, 100, 110, '2008-10-15', 3000, 7, 3000);
#
# ````

# %% [markdown]
# ![image.png](attachment:5c9eaa3c-16ea-4723-943e-abe3a230598c.png)

# %% [markdown]
# ````sql
#
# INSERT INTO ORDERS VALUES
# (1, '2018-01-25', '2018-03-15'),
# (7, '2018-02-14', '2018-03-02'),
# (1, '2018-06-15', '2018-07-15'),
# (5, '2019-04-15', '2019-05-10'),
# (8, '2019-04-20', '2019-06-15'),
# (4, '2020-12-15', '2021-01-30'),
# (1, '2021-04-08', '2021-04-30'),
# (6, '2017-12-14', '2018-01-20'),
# (9, '2019-08-14', '2019-09-01');
#
# ````

# %% [markdown]
# ![image.png](attachment:938331c0-13c2-40f2-9c72-ff2d8d465291.png)

# %% [markdown]
# ````sql
#
# SET IDENTITY_INSERT TITLES ON;
#
# INSERT INTO TITLES (B_ID, A_ID, A_NO, A_FEE) VALUES
# (6, 1, 1, 100),
# (7, 4, 1, 100),
# (9, 3, 1, 100),
# (10, 5, 1, 84),
# (8, 2, 1, 100);
#
# SET IDENTITY_INSERT TITLES OFF;
#
# ````

# %% [markdown]
# #### IDENTITY_INSERT в положении ON позволяет вам задавать значения идентификаторов, а OFF возвращает столбец к автоинкрементным значениям.
# ![image.png](attachment:793e8162-26c0-4e84-ba4f-66e6d30e6dd6.png)

# %% [markdown]
# ##
# ````sql
# INSERT INTO ITEMS VALUES
# ( 1, 6, 10),
# ( 2, 7, 15),
# ( 2, 9, 15),
# ( 1, 9, 10),
# (3 , 8, 1),
# ( 3, 10, 10),
# ( 3, 6, 15),
# ( 4, 6, 7),
# ( 5, 8, 4),
# ( 6, 7, 5),
# ( 6, 10, 80),
# ( 7, 9, 50),
# ( 8, 6, 10),
# ( 9, 10, 1),
# ( 9, 8, 2);
#
# ````

# %% [markdown]
# ![image.png](attachment:c27325b9-7f9f-43a9-8c16-1cb688aeee84.png)

# %% [markdown]
# ##
# ````sql
# INSERT INTO EDITORS VALUES
# (6, 3),
# (7, 3),
# (8, 5),
# (9, 8),
# (10, 3);
#
#
# ````

# %% [markdown]
# ![image.png](attachment:6881bc6f-883c-4d85-b659-ad74b8086c70.png)
