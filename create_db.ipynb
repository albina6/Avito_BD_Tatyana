# %% [markdown]
# ## Для восстановления бд необходимо:
# 1.	открыть MS SQL Server,
# 2.	создать новую бд с нужным названием,
# 3.	открыть окно для ввода скрипта (выбрать созданную бд, нажать правой кнопкой мыши ),
# 4.	ввести код,
# 5.	выполнить его
#
# Создать новую бд
# * повторить пункты выше для другого кода

# %% [markdown]
# ![image.png](attachment:04ad7aa4-715c-4ecd-998f-355b7d739863.png)

# %% [markdown]
# ![image.png](attachment:f51b24cc-29ec-402e-bb21-d81cd49923fc.png)

# %% [markdown]
# ![image.png](attachment:558b3eb2-d9be-4ccd-970b-ffec9620026b.png)

# %% [markdown]
# ![image.png](attachment:2f47dd68-7ec4-43da-a111-1e9bca5db887.png)

# %% [markdown]
# # Код для 3 лабы (общая часть), с этой бд работает код из файла 3_lab_indiv.ipynb

# %%
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CATALOGS](
	[ID_CATALOG] [int] IDENTITY(1,1) NOT NULL,
	[NAME] [nchar](20) NOT NULL,
 CONSTRAINT [PK_CATALOGS] PRIMARY KEY CLUSTERED 
(
	[ID_CATALOG] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO
/****** Object:  Table [dbo].[ORDERS]    Script Date: 18.06.2024 12:17:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ORDERS](
	[ID_ORDER] [int] IDENTITY(1,1) NOT NULL,
	[ID_USER] [int] NOT NULL,
	[ORDERTIME] [date] NOT NULL,
	[NUMBER] [int] NOT NULL,
	[ID_PRODUCT] [int] NOT NULL,
 CONSTRAINT [PK_ORDERS] PRIMARY KEY CLUSTERED 
(
	[ID_ORDER] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO
/****** Object:  Table [dbo].[PRODUCTS]    Script Date: 18.06.2024 12:17:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PRODUCTS](
	[ID_PRODUCT] [int] IDENTITY(1,1) NOT NULL,
	[NAME] [nchar](50) NOT NULL,
	[PRICE] [decimal](10, 2) NOT NULL,
	[COUNT] [int] NOT NULL,
	[MARK] [decimal](3, 1) NOT NULL,
	[DESCRIPTION] [nchar](100) NULL,
	[ID_CATALOG] [int] NOT NULL,
 CONSTRAINT [PK_PRODUCTS] PRIMARY KEY CLUSTERED 
(
	[ID_PRODUCT] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO
/****** Object:  Table [dbo].[USERS]    Script Date: 18.06.2024 12:17:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[USERS](
	[ID_USER] [int] IDENTITY(1,1) NOT NULL,
	[SURNAME] [nchar](30) NOT NULL,
	[PATRONIMIC] [nchar](30) NOT NULL,
	[NAME] [nchar](30) NOT NULL,
	[PHONE] [nchar](12) NULL,
	[EMAIL] [nchar](25) NOT NULL,
	[URL] [nchar](50) NULL,
	[USERSTATUS] [nchar](10) NOT NULL,
 CONSTRAINT [PK_USERS] PRIMARY KEY CLUSTERED 
(
	[ID_USER] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO
SET IDENTITY_INSERT [dbo].[CATALOGS] ON 
GO
INSERT [dbo].[CATALOGS] ([ID_CATALOG], [NAME]) VALUES (1, N'Процессоры          ')
GO
INSERT [dbo].[CATALOGS] ([ID_CATALOG], [NAME]) VALUES (2, N'Материнские платы   ')
GO
INSERT [dbo].[CATALOGS] ([ID_CATALOG], [NAME]) VALUES (3, N'Видеоадаптеры       ')
GO
INSERT [dbo].[CATALOGS] ([ID_CATALOG], [NAME]) VALUES (4, N'Жесткие диски       ')
GO
INSERT [dbo].[CATALOGS] ([ID_CATALOG], [NAME]) VALUES (5, N'Оперативная память  ')
GO
SET IDENTITY_INSERT [dbo].[CATALOGS] OFF
GO
SET IDENTITY_INSERT [dbo].[ORDERS] ON 
GO
INSERT [dbo].[ORDERS] ([ID_ORDER], [ID_USER], [ORDERTIME], [NUMBER], [ID_PRODUCT]) VALUES (1, 3, CAST(N'2005-04-01' AS Date), 1, 8)
GO
INSERT [dbo].[ORDERS] ([ID_ORDER], [ID_USER], [ORDERTIME], [NUMBER], [ID_PRODUCT]) VALUES (2, 6, CAST(N'2005-10-02' AS Date), 2, 10)
GO
INSERT [dbo].[ORDERS] ([ID_ORDER], [ID_USER], [ORDERTIME], [NUMBER], [ID_PRODUCT]) VALUES (3, 1, CAST(N'2005-02-18' AS Date), 4, 20)
GO
INSERT [dbo].[ORDERS] ([ID_ORDER], [ID_USER], [ORDERTIME], [NUMBER], [ID_PRODUCT]) VALUES (4, 3, CAST(N'2005-10-03' AS Date), 1, 20)
GO
INSERT [dbo].[ORDERS] ([ID_ORDER], [ID_USER], [ORDERTIME], [NUMBER], [ID_PRODUCT]) VALUES (5, 3, CAST(N'2005-03-17' AS Date), 1, 20)
GO
INSERT [dbo].[ORDERS] ([ID_ORDER], [ID_USER], [ORDERTIME], [NUMBER], [ID_PRODUCT]) VALUES (7, 4, CAST(N'2005-01-06' AS Date), 12, 28)
GO
SET IDENTITY_INSERT [dbo].[ORDERS] OFF
GO
SET IDENTITY_INSERT [dbo].[PRODUCTS] ON 
GO
INSERT [dbo].[PRODUCTS] ([ID_PRODUCT], [NAME], [PRICE], [COUNT], [MARK], [DESCRIPTION], [ID_CATALOG]) VALUES (1, N'Celeron 1.8                                       ', CAST(1595.00 AS Decimal(10, 2)), 10, CAST(3.6 AS Decimal(3, 1)), N'Процессор  Celeron® 1.8GHz. 128kb. 478-PGA. 400Mhz. OEM 0.18                                        ', 1)
GO
INSERT [dbo].[PRODUCTS] ([ID_PRODUCT], [NAME], [PRICE], [COUNT], [MARK], [DESCRIPTION], [ID_CATALOG]) VALUES (2, N'Celeron 2.0GHz                                    ', CAST(1969.00 AS Decimal(10, 2)), 2, CAST(3.7 AS Decimal(3, 1)), N'Процессор  Celeron® 2.0GHz. 128kb. 478-PGA. 400Mhz. OEM 0.18                                        ', 1)
GO
INSERT [dbo].[PRODUCTS] ([ID_PRODUCT], [NAME], [PRICE], [COUNT], [MARK], [DESCRIPTION], [ID_CATALOG]) VALUES (3, N'Celeron 2.4GHz                                    ', CAST(2109.00 AS Decimal(10, 2)), 4, CAST(3.9 AS Decimal(3, 1)), N'Процессор  Celeron® 2.4GHz. 128kb. 478-PGA. 400Mhz. OEM                                             ', 1)
GO
INSERT [dbo].[PRODUCTS] ([ID_PRODUCT], [NAME], [PRICE], [COUNT], [MARK], [DESCRIPTION], [ID_CATALOG]) VALUES (4, N'Celeron D 320 2.4GHz                              ', CAST(1962.00 AS Decimal(10, 2)), 1, CAST(4.1 AS Decimal(3, 1)), N'Процессор  Celeron® D 320 2.4GHz. 256kb. 478-PGA. 533Mhz. OEM                                       ', 1)
GO
INSERT [dbo].[PRODUCTS] ([ID_PRODUCT], [NAME], [PRICE], [COUNT], [MARK], [DESCRIPTION], [ID_CATALOG]) VALUES (5, N'Celeron D 325 2.53GHz                             ', CAST(2747.00 AS Decimal(10, 2)), 6, CAST(4.1 AS Decimal(3, 1)), N'Процессор  Celeron® D 325 2.53GHz. 256kb. 478-PGA. 533Mhz. OEM                                      ', 1)
GO
INSERT [dbo].[PRODUCTS] ([ID_PRODUCT], [NAME], [PRICE], [COUNT], [MARK], [DESCRIPTION], [ID_CATALOG]) VALUES (6, N'Celeron D 315 2.26GHz                             ', CAST(188.00 AS Decimal(10, 2)), 6, CAST(4.1 AS Decimal(3, 1)), N'Процессор  Celeron® D 315 2.26GHz. 256kb. 478-PGA. 533Mhz. OEM                                      ', 1)
GO
INSERT [dbo].[PRODUCTS] ([ID_PRODUCT], [NAME], [PRICE], [COUNT], [MARK], [DESCRIPTION], [ID_CATALOG]) VALUES (7, N'Intel Pentium 4 3.2GHz                            ', CAST(7259.00 AS Decimal(10, 2)), 5, CAST(4.5 AS Decimal(3, 1)), N'Процессор  Intel® Pentium®4 3.2GHz. 1Mb. 478-PGA. 400Mhz. OEM..                                     ', 1)
GO
INSERT [dbo].[PRODUCTS] ([ID_PRODUCT], [NAME], [PRICE], [COUNT], [MARK], [DESCRIPTION], [ID_CATALOG]) VALUES (8, N'Intel Pentium 4 3.0GHz                            ', CAST(6147.00 AS Decimal(10, 2)), 1, CAST(4.6 AS Decimal(3, 1)), N'Процессор  Intel® Pentium®4 3.0GHz. 512kb. 478-PGA. 400Mhz. OEM..                                   ', 1)
GO
INSERT [dbo].[PRODUCTS] ([ID_PRODUCT], [NAME], [PRICE], [COUNT], [MARK], [DESCRIPTION], [ID_CATALOG]) VALUES (9, N'Intel Pentium 4 3.0GHz                            ', CAST(5673.00 AS Decimal(10, 2)), 12, CAST(4.5 AS Decimal(3, 1)), N'Процессор  Intel® Pentium®4 3.0GHz. 1Mb. 478-PGA. 400Mhz. OEM..                                     ', 1)
GO
INSERT [dbo].[PRODUCTS] ([ID_PRODUCT], [NAME], [PRICE], [COUNT], [MARK], [DESCRIPTION], [ID_CATALOG]) VALUES (10, N'Gigabyte GA-81848P-RS                             ', CAST(1896.00 AS Decimal(10, 2)), 4, CAST(3.9 AS Decimal(3, 1)), N'Материнская плата GIGABYTE GA-8I848P (GA-8I848P-RS)                                                 ', 2)
GO
INSERT [dbo].[PRODUCTS] ([ID_PRODUCT], [NAME], [PRICE], [COUNT], [MARK], [DESCRIPTION], [ID_CATALOG]) VALUES (11, N'Gigabyte GA-81G1000                               ', CAST(2420.00 AS Decimal(10, 2)), 2, CAST(3.8 AS Decimal(3, 1)), N'Материнская плата GIGABYTE GA-81G1000 (GA-81G1000)                                                  ', 2)
GO
INSERT [dbo].[PRODUCTS] ([ID_PRODUCT], [NAME], [PRICE], [COUNT], [MARK], [DESCRIPTION], [ID_CATALOG]) VALUES (12, N'Gigabyte GA-81PE1000G                             ', CAST(2289.00 AS Decimal(10, 2)), 6, CAST(3.8 AS Decimal(3, 1)), N'Материнская плата GIGABYTE GA-81PE1000G                                                             ', 2)
GO
INSERT [dbo].[PRODUCTS] ([ID_PRODUCT], [NAME], [PRICE], [COUNT], [MARK], [DESCRIPTION], [ID_CATALOG]) VALUES (13, N'Asustek P4C800-E Delux                            ', CAST(5395.00 AS Decimal(10, 2)), 4, CAST(4.1 AS Decimal(3, 1)), N'Материнская плата Asustek P4C800-E Delux                                                            ', 2)
GO
INSERT [dbo].[PRODUCTS] ([ID_PRODUCT], [NAME], [PRICE], [COUNT], [MARK], [DESCRIPTION], [ID_CATALOG]) VALUES (14, N'Asustek P4C800-VM\\Li865G                         ', CAST(2518.00 AS Decimal(10, 2)), 6, CAST(4.0 AS Decimal(3, 1)), N'Материнская плата Asustek P4C800-VM\\Li865G                                                         ', 2)
GO
INSERT [dbo].[PRODUCTS] ([ID_PRODUCT], [NAME], [PRICE], [COUNT], [MARK], [DESCRIPTION], [ID_CATALOG]) VALUES (15, N'Epox ep-4PDA31                                    ', CAST(2289.00 AS Decimal(10, 2)), 5, CAST(4.0 AS Decimal(3, 1)), N'Материнская плата Epox ep-4PDA31                                                                    ', 2)
GO
INSERT [dbo].[PRODUCTS] ([ID_PRODUCT], [NAME], [PRICE], [COUNT], [MARK], [DESCRIPTION], [ID_CATALOG]) VALUES (16, N'ASUSTEK A9600XT/TD                                ', CAST(5156.00 AS Decimal(10, 2)), 2, CAST(4.7 AS Decimal(3, 1)), N'Видеоадаптер ASUSTEK A9600XT/TD                                                                     ', 3)
GO
INSERT [dbo].[PRODUCTS] ([ID_PRODUCT], [NAME], [PRICE], [COUNT], [MARK], [DESCRIPTION], [ID_CATALOG]) VALUES (17, N'ASUSTEK V9520X                                    ', CAST(1602.00 AS Decimal(10, 2)), 6, CAST(4.0 AS Decimal(3, 1)), N'Видеоадаптер ASUSTEK V9520X                                                                         ', 3)
GO
INSERT [dbo].[PRODUCTS] ([ID_PRODUCT], [NAME], [PRICE], [COUNT], [MARK], [DESCRIPTION], [ID_CATALOG]) VALUES (18, N'SAPPHIRE 25MB RADEON 9550                         ', CAST(2730.00 AS Decimal(10, 2)), 3, CAST(3.8 AS Decimal(3, 1)), N'ВИДЕОКАРТА SAPPHIRE 25MB RADEON 9550                                                                ', 3)
GO
INSERT [dbo].[PRODUCTS] ([ID_PRODUCT], [NAME], [PRICE], [COUNT], [MARK], [DESCRIPTION], [ID_CATALOG]) VALUES (19, N'GIGABYTE AGP GV-N59X128D                          ', CAST(5886.00 AS Decimal(10, 2)), 6, CAST(3.6 AS Decimal(3, 1)), N'ВИДЕОКАРТА GIGABYTE AGP GV-N59X128D                                                                 ', 3)
GO
INSERT [dbo].[PRODUCTS] ([ID_PRODUCT], [NAME], [PRICE], [COUNT], [MARK], [DESCRIPTION], [ID_CATALOG]) VALUES (20, N'Maxtor 6Y120P0                                    ', CAST(2456.00 AS Decimal(10, 2)), 6, CAST(4.5 AS Decimal(3, 1)), N'Винчестер Maxtor 6Y120P0                                                                            ', 4)
GO
INSERT [dbo].[PRODUCTS] ([ID_PRODUCT], [NAME], [PRICE], [COUNT], [MARK], [DESCRIPTION], [ID_CATALOG]) VALUES (21, N'Maxtor 6B200P0                                    ', CAST(3589.00 AS Decimal(10, 2)), 4, CAST(4.0 AS Decimal(3, 1)), N'Винчестер Maxtor 6B200P0                                                                            ', 4)
GO
INSERT [dbo].[PRODUCTS] ([ID_PRODUCT], [NAME], [PRICE], [COUNT], [MARK], [DESCRIPTION], [ID_CATALOG]) VALUES (22, N'SAMSUNG SP0812C                                   ', CAST(2093.00 AS Decimal(10, 2)), 5, CAST(4.0 AS Decimal(3, 1)), N'Винчестер SAMSUNG SP0812C                                                                           ', 4)
GO
INSERT [dbo].[PRODUCTS] ([ID_PRODUCT], [NAME], [PRICE], [COUNT], [MARK], [DESCRIPTION], [ID_CATALOG]) VALUES (23, N'Seagate Barracuda ST3160023A                      ', CAST(3139.00 AS Decimal(10, 2)), 3, CAST(4.1 AS Decimal(3, 1)), N'Винчестер Barracuda ST3160023A                                                                      ', 4)
GO
INSERT [dbo].[PRODUCTS] ([ID_PRODUCT], [NAME], [PRICE], [COUNT], [MARK], [DESCRIPTION], [ID_CATALOG]) VALUES (24, N'Seagate ST3160023A                                ', CAST(2468.00 AS Decimal(10, 2)), 8, CAST(4.2 AS Decimal(3, 1)), N'Винчестер  ST3160023A                                                                               ', 4)
GO
INSERT [dbo].[PRODUCTS] ([ID_PRODUCT], [NAME], [PRICE], [COUNT], [MARK], [DESCRIPTION], [ID_CATALOG]) VALUES (25, N'DDR-400 256MB Kingston                            ', CAST(1085.00 AS Decimal(10, 2)), 20, CAST(4.8 AS Decimal(3, 1)), N'Оперативная память DDR-400 256MB Kingston                                                           ', 5)
GO
INSERT [dbo].[PRODUCTS] ([ID_PRODUCT], [NAME], [PRICE], [COUNT], [MARK], [DESCRIPTION], [ID_CATALOG]) VALUES (26, N'DDR-400 256MB Hynix Original                      ', CAST(1179.00 AS Decimal(10, 2)), 15, CAST(4.6 AS Decimal(3, 1)), N'Оперативная память DDR-400 256MB Hnix Original                                                      ', 5)
GO
INSERT [dbo].[PRODUCTS] ([ID_PRODUCT], [NAME], [PRICE], [COUNT], [MARK], [DESCRIPTION], [ID_CATALOG]) VALUES (27, N'DDR-400 256MB PQI                                 ', CAST(899.00 AS Decimal(10, 2)), 10, CAST(4.2 AS Decimal(3, 1)), N'Оперативная память DDR-400 256MB Hnix Original                                                      ', 5)
GO
INSERT [dbo].[PRODUCTS] ([ID_PRODUCT], [NAME], [PRICE], [COUNT], [MARK], [DESCRIPTION], [ID_CATALOG]) VALUES (28, N'DDR-400 512MB Kingston                            ', CAST(1932.00 AS Decimal(10, 2)), 8, CAST(4.8 AS Decimal(3, 1)), N'Оперативная память DDR-400 512MB Kingston                                                           ', 5)
GO
INSERT [dbo].[PRODUCTS] ([ID_PRODUCT], [NAME], [PRICE], [COUNT], [MARK], [DESCRIPTION], [ID_CATALOG]) VALUES (29, N'DDR-400 512MB PQI                                 ', CAST(1690.00 AS Decimal(10, 2)), 12, CAST(4.2 AS Decimal(3, 1)), N'Оперативная память DDR-400 512MB PQI                                                                ', 5)
GO
INSERT [dbo].[PRODUCTS] ([ID_PRODUCT], [NAME], [PRICE], [COUNT], [MARK], [DESCRIPTION], [ID_CATALOG]) VALUES (30, N'DDR-400 512MB Hynix                               ', CAST(1717.00 AS Decimal(10, 2)), 8, CAST(4.5 AS Decimal(3, 1)), N'Оперативная память DDR-400 512MB Hynix                                                              ', 5)
GO
SET IDENTITY_INSERT [dbo].[PRODUCTS] OFF
GO
SET IDENTITY_INSERT [dbo].[USERS] ON 
GO
INSERT [dbo].[USERS] ([ID_USER], [SURNAME], [PATRONIMIC], [NAME], [PHONE], [EMAIL], [URL], [USERSTATUS]) VALUES (1, N'Иванов                        ', N'Валерьевич                    ', N'Александр                     ', N'58-98-78    ', N'ivaov@email.ru           ', NULL, N'active    ')
GO
INSERT [dbo].[USERS] ([ID_USER], [SURNAME], [PATRONIMIC], [NAME], [PHONE], [EMAIL], [URL], [USERSTATUS]) VALUES (2, N'Прокопчук                     ', N'Иванович                      ', N'Сергей                        ', N'9057777777  ', N'pro@email.ru             ', NULL, N'passive   ')
GO
INSERT [dbo].[USERS] ([ID_USER], [SURNAME], [PATRONIMIC], [NAME], [PHONE], [EMAIL], [URL], [USERSTATUS]) VALUES (3, N'Семенов                       ', N'Вячеславович                  ', N'Игорь                         ', N'905666100   ', N'simdyanov@softtime.ru    ', N'http://www.softtime.ru                            ', N'active    ')
GO
INSERT [dbo].[USERS] ([ID_USER], [SURNAME], [PATRONIMIC], [NAME], [PHONE], [EMAIL], [URL], [USERSTATUS]) VALUES (4, N'Петров                        ', N'Валерьевич                    ', N'Максим                        ', NULL, N'kuznetsov@softtime.ru    ', N'http://www.softtime.ru                            ', N'active    ')
GO
INSERT [dbo].[USERS] ([ID_USER], [SURNAME], [PATRONIMIC], [NAME], [PHONE], [EMAIL], [URL], [USERSTATUS]) VALUES (5, N'Лосев                         ', N'Юрьевич                       ', N'Анатолий                      ', NULL, N'losev@email.ru           ', NULL, N'lock      ')
GO
INSERT [dbo].[USERS] ([ID_USER], [SURNAME], [PATRONIMIC], [NAME], [PHONE], [EMAIL], [URL], [USERSTATUS]) VALUES (6, N'Корнеев                       ', N'Александрович                 ', N'Александр                     ', N'89-7836     ', N'korneev@email.ru         ', NULL, N'gold      ')
GO
INSERT [dbo].[USERS] ([ID_USER], [SURNAME], [PATRONIMIC], [NAME], [PHONE], [EMAIL], [URL], [USERSTATUS]) VALUES (9, N'Кремнева                      ', N'Александровна                 ', N'Александра                    ', N'9058956458  ', N'cremneva@mail.ru         ', N'cremnera.tomsk.ru                                 ', N'passive   ')
GO
INSERT [dbo].[USERS] ([ID_USER], [SURNAME], [PATRONIMIC], [NAME], [PHONE], [EMAIL], [URL], [USERSTATUS]) VALUES (10, N'Громова                       ', N'Валерьевна                    ', N'Анна                          ', N'55-66-89    ', N'grom_ann@mail.ru         ', NULL, N'active    ')
GO
INSERT [dbo].[USERS] ([ID_USER], [SURNAME], [PATRONIMIC], [NAME], [PHONE], [EMAIL], [URL], [USERSTATUS]) VALUES (11, N'Кремнева                      ', N'Александровна                 ', N'Александра                    ', N'9058956458  ', N'cremneva@mail.ru         ', NULL, N'passive   ')
GO
INSERT [dbo].[USERS] ([ID_USER], [SURNAME], [PATRONIMIC], [NAME], [PHONE], [EMAIL], [URL], [USERSTATUS]) VALUES (12, N'Громова                       ', N'Валерьевна                    ', N'Анна                          ', N'55-66-89    ', N'grom_ann@mail.ru         ', NULL, N'active    ')
GO
INSERT [dbo].[USERS] ([ID_USER], [SURNAME], [PATRONIMIC], [NAME], [PHONE], [EMAIL], [URL], [USERSTATUS]) VALUES (13, N'Кремнева                      ', N'Александровна                 ', N'Александра                    ', N'9058956458  ', N'cremneva@mail.ru         ', NULL, N'passive   ')
GO
SET IDENTITY_INSERT [dbo].[USERS] OFF
GO
ALTER TABLE [dbo].[ORDERS]  WITH CHECK ADD  CONSTRAINT [FK_ORDERS_PRODUCTS] FOREIGN KEY([ID_PRODUCT])
REFERENCES [dbo].[PRODUCTS] ([ID_PRODUCT])
ON UPDATE CASCADE
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[ORDERS] CHECK CONSTRAINT [FK_ORDERS_PRODUCTS]
GO
ALTER TABLE [dbo].[ORDERS]  WITH CHECK ADD  CONSTRAINT [FK_ORDERS_USERS] FOREIGN KEY([ID_USER])
REFERENCES [dbo].[USERS] ([ID_USER])
ON UPDATE CASCADE
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[ORDERS] CHECK CONSTRAINT [FK_ORDERS_USERS]
GO
ALTER TABLE [dbo].[PRODUCTS]  WITH CHECK ADD  CONSTRAINT [FK_PRODUCTS_CATALOGS] FOREIGN KEY([ID_CATALOG])
REFERENCES [dbo].[CATALOGS] ([ID_CATALOG])
ON UPDATE CASCADE
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[PRODUCTS] CHECK CONSTRAINT [FK_PRODUCTS_CATALOGS]
GO
/****** Object:  Trigger [dbo].[NUMBER_UPDATE]    Script Date: 18.06.2024 12:17:06 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TRIGGER [dbo].[NUMBER_UPDATE]
	ON [dbo].[ORDERS]
	AFTER INSERT
AS
DECLARE @X INT, @Y INT
BEGIN 
	  SET NOCOUNT ON;
	  IF NOT EXISTS
	  (
		SELECT * 
		  FROM inserted
		 WHERE inserted.NUMBER <= ALL
		 ( 
			SELECT PRODUCTS.COUNT
			  FROM PRODUCTS
			  WHERE inserted.ID_PRODUCT = PRODUCTS.ID_PRODUCT
		 )
	   ) BEGIN
			ROLLBACK TRAN
			PRINT 'Откат! Такого количества товара нет на складе!';
		 END;
	   SELECT @Y = temp_ist.ID_PRODUCT,
			  @X = temp_ist.NUMBER
		 FROM inserted AS temp_ist
	   UPDATE PRODUCTS
	      SET PRODUCTS.COUNT = PRODUCTS.COUNT - @X
		WHERE PRODUCTS.ID_PRODUCT = @Y
END;


GO
ALTER TABLE [dbo].[ORDERS] ENABLE TRIGGER [NUMBER_UPDATE]
GO
/****** Object:  Trigger [dbo].[ROLLBACK_EXAMPLE]    Script Date: 18.06.2024 12:17:36 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TRIGGER [dbo].[ROLLBACK_EXAMPLE]
	ON [dbo].[ORDERS]
	AFTER INSERT
AS
BEGIN 
	  SET NOCOUNT ON;
	  IF (SELECT NUMBER FROM inserted) < 1
	  BEGIN
		ROLLBACK;
		PRINT 'Вы не можете создать заказ с количеством меньше 1';
	  END;
END;


GO
ALTER TABLE [dbo].[ORDERS] ENABLE TRIGGER [ROLLBACK_EXAMPLE]
GO
/****** Object:  Trigger [dbo].[DELETE_INDICATION]    Script Date: 18.06.2024 12:18:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TRIGGER [dbo].[DELETE_INDICATION]
	ON [dbo].[USERS]
	AFTER DELETE 
AS
BEGIN 
	  SET NOCOUNT ON;
	  PRINT 'Запись удалена';
END;


GO
ALTER TABLE [dbo].[USERS] ENABLE TRIGGER [DELETE_INDICATION]
GO
/****** Object:  Trigger [dbo].[INSETT_INDICATION]    Script Date: 18.06.2024 12:19:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE TRIGGER [dbo].[INSETT_INDICATION]
	ON [dbo].[USERS] AFTER INSERT 
AS
BEGIN 
	  SET NOCOUNT ON;
	  PRINT 'Запись добавлена в таблицу USE';
END

GO
ALTER TABLE [dbo].[USERS] ENABLE TRIGGER [INSETT_INDICATION]
GO
/****** Object:  Trigger [dbo].[UPDATE_INDICATION]    Script Date: 18.06.2024 12:21:19 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TRIGGER [dbo].[UPDATE_INDICATION]
	ON [dbo].[USERS]
	AFTER UPDATE 
AS
BEGIN 
	  SET NOCOUNT ON;
	  PRINT 'Запись изменена';
END
GO
ALTER TABLE [dbo].[USERS] ENABLE TRIGGER [UPDATE_INDICATION]
GO

# %% [markdown]
# # Код для 2,3,4 лабы (бд из 1 лабораторной), с этой бд работает код из файлов 2_lab.ipynb, 3_lab_indiv.ipynb, 4_lab.ipynb

# %%
/****** Object:  Table [dbo].[AUTHORS]    Script Date: 18.06.2024 12:48:51 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AUTHORS](
	[A_ID] [int] IDENTITY(1,1) NOT NULL,
	[A_FNAME] [nchar](20) NOT NULL,
	[A_LNAME] [nchar](30) NOT NULL,
	[A_INN] [nchar](12) NOT NULL,
	[A_PASSP] [nchar](12) NOT NULL,
	[A_ORG] [nchar](30) NOT NULL,
	[A_PDATE] [date] NOT NULL,
	[A_ADDR] [nchar](50) NOT NULL,
	[A_TEL] [nchar](30) NOT NULL,
 CONSTRAINT [PK_AUTHORS] PRIMARY KEY CLUSTERED 
(
	[A_ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO
/****** Object:  Table [dbo].[BOOKS]    Script Date: 18.06.2024 12:48:51 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[BOOKS](
	[B_CONTRACT] [int] IDENTITY(1,1) NOT NULL,
	[B_DATE] [date] NULL,
	[B_MAN] [int] NULL,
	[B_TITLE] [nchar](40) NULL,
	[B_PRICE] [decimal](6, 2) NULL,
	[B_ADVANCE] [decimal](10, 2) NULL,
	[B_FEE] [decimal](8, 2) NULL,
	[B_PUBL] [date] NOT NULL,
	[B_CIRCUL] [int] NOT NULL,
	[B_EDIT] [int] NULL,
	[B_REST] [int] NOT NULL,
 CONSTRAINT [PK_BOOKS] PRIMARY KEY CLUSTERED 
(
	[B_CONTRACT] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO
/****** Object:  Table [dbo].[CUSTOMERS]    Script Date: 18.06.2024 12:48:51 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CUSTOMERS](
	[C_ID] [int] IDENTITY(1,1) NOT NULL,
	[C_NAME] [nchar](30) NOT NULL,
	[C_ADDR] [nchar](50) NOT NULL,
 CONSTRAINT [PK_CUSTOMERS] PRIMARY KEY CLUSTERED 
(
	[C_ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO
/****** Object:  Table [dbo].[EDITORS]    Script Date: 18.06.2024 12:48:51 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[EDITORS](
	[B_ID] [int] NOT NULL,
	[E_ID] [int] NOT NULL
) ON [PRIMARY]
GO
/****** Object:  Table [dbo].[EMPLOYEES]    Script Date: 18.06.2024 12:48:51 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[EMPLOYEES](
	[E_ID] [int] IDENTITY(1,1) NOT NULL,
	[E_FNAME] [nchar](20) NOT NULL,
	[E_LNAME] [nchar](30) NOT NULL,
	[E_BORN] [date] NULL,
	[E_SEX] [bit] NOT NULL,
	[E_POST] [int] NOT NULL,
	[E_ROOM] [int] NULL,
	[E_TEL] [nchar](10) NULL,
	[E_INN] [nchar](12) NOT NULL,
	[E_PASSP] [nchar](12) NOT NULL,
	[E_ORG] [nchar](30) NOT NULL,
	[E_PDATE] [date] NOT NULL,
	[E_ADDR] [nchar](50) NULL,
 CONSTRAINT [PK_EMPLOYEES] PRIMARY KEY CLUSTERED 
(
	[E_ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO
/****** Object:  Table [dbo].[ITEMS]    Script Date: 18.06.2024 12:48:51 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ITEMS](
	[O_ID] [int] NOT NULL,
	[B_ID] [int] NOT NULL,
	[B_COUNT] [int] NOT NULL
) ON [PRIMARY]
GO
/****** Object:  Table [dbo].[ORDERS]    Script Date: 18.06.2024 12:48:51 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ORDERS](
	[O_ID] [int] IDENTITY(1,1) NOT NULL,
	[O_COMPANY] [int] NOT NULL,
	[O_DATE] [date] NOT NULL,
	[O_READY] [date] NULL,
PRIMARY KEY CLUSTERED 
(
	[O_ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO
/****** Object:  Table [dbo].[POSTS]    Script Date: 18.06.2024 12:48:51 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[POSTS](
	[P_ID] [int] IDENTITY(1,1) NOT NULL,
	[P_POST] [nchar](30) NOT NULL,
	[P_SAL] [decimal](8, 2) NOT NULL,
 CONSTRAINT [PK_POSTS] PRIMARY KEY CLUSTERED 
(
	[P_ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO
/****** Object:  Table [dbo].[ROOMS]    Script Date: 18.06.2024 12:48:51 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ROOMS](
	[R_NO] [int] NOT NULL,
	[R_TEL] [nchar](10) NOT NULL,
 CONSTRAINT [PK_ROOMS] PRIMARY KEY CLUSTERED 
(
	[R_NO] ASC,
	[R_TEL] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO
/****** Object:  Table [dbo].[TITLES]    Script Date: 18.06.2024 12:48:51 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TITLES](
	[B_ID] [int] IDENTITY(1,1) NOT NULL,
	[A_ID] [int] NOT NULL,
	[A_NO] [int] NOT NULL,
	[A_FEE] [decimal](3, 0) NOT NULL
) ON [PRIMARY]
GO
SET IDENTITY_INSERT [dbo].[AUTHORS] ON 
GO
INSERT [dbo].[AUTHORS] ([A_ID], [A_FNAME], [A_LNAME], [A_INN], [A_PASSP], [A_ORG], [A_PDATE], [A_ADDR], [A_TEL]) VALUES (1, N'Булгаков            ', N'Михаил                        ', N'178495482355', N'1475 148527 ', N'г. Москва, МВД по             ', CAST(N'1930-03-10' AS Date), N'г. Москва, ул.                                    ', N'142548                        ')
GO
INSERT [dbo].[AUTHORS] ([A_ID], [A_FNAME], [A_LNAME], [A_INN], [A_PASSP], [A_ORG], [A_PDATE], [A_ADDR], [A_TEL]) VALUES (2, N'Гоголь              ', N'Николай                       ', N'1792004584  ', N'1424 364572 ', N'МВД по РБ                     ', CAST(N'2008-12-03' AS Date), N'г. Москва, ул.                                    ', N'15-48-84                      ')
GO
INSERT [dbo].[AUTHORS] ([A_ID], [A_FNAME], [A_LNAME], [A_INN], [A_PASSP], [A_ORG], [A_PDATE], [A_ADDR], [A_TEL]) VALUES (3, N'Пушкин              ', N'Александр                     ', N'845744571941', N'1447 551002 ', N'МВД по МО                     ', CAST(N'2013-03-14' AS Date), N'г. Уфа, ул.                                       ', N'948-785-4874                  ')
GO
INSERT [dbo].[AUTHORS] ([A_ID], [A_FNAME], [A_LNAME], [A_INN], [A_PASSP], [A_ORG], [A_PDATE], [A_ADDR], [A_TEL]) VALUES (4, N'Достоевский         ', N'Федор                         ', N'486140355671', N'2205 128845 ', N'МВД по МО                     ', CAST(N'2014-10-12' AS Date), N'г. Уфа, ул.                                       ', N'987-484-7850                  ')
GO
INSERT [dbo].[AUTHORS] ([A_ID], [A_FNAME], [A_LNAME], [A_INN], [A_PASSP], [A_ORG], [A_PDATE], [A_ADDR], [A_TEL]) VALUES (5, N'Донцова             ', N'Дарья                         ', N'175229443378', N'1240 748758 ', N'МВД по МО                     ', CAST(N'2003-12-01' AS Date), N'г. Москва, ул.                                    ', N'74-84-79                      ')
GO
SET IDENTITY_INSERT [dbo].[AUTHORS] OFF
GO
SET IDENTITY_INSERT [dbo].[BOOKS] ON 
GO
INSERT [dbo].[BOOKS] ([B_CONTRACT], [B_DATE], [B_MAN], [B_TITLE], [B_PRICE], [B_ADVANCE], [B_FEE], [B_PUBL], [B_CIRCUL], [B_EDIT], [B_REST]) VALUES (6, CAST(N'2001-12-04' AS Date), 3, N'Мастер и Маргарита                      ', CAST(1200.00 AS Decimal(6, 2)), CAST(500.00 AS Decimal(10, 2)), CAST(200.00 AS Decimal(8, 2)), CAST(N'2002-02-13' AS Date), 1100, 4, 1100)
GO
INSERT [dbo].[BOOKS] ([B_CONTRACT], [B_DATE], [B_MAN], [B_TITLE], [B_PRICE], [B_ADVANCE], [B_FEE], [B_PUBL], [B_CIRCUL], [B_EDIT], [B_REST]) VALUES (7, CAST(N'2010-04-22' AS Date), 4, N'Преступление и наказание                ', CAST(2500.00 AS Decimal(6, 2)), CAST(1000.00 AS Decimal(10, 2)), CAST(500.00 AS Decimal(8, 2)), CAST(N'2010-10-05' AS Date), 2000, 7, 2000)
GO
INSERT [dbo].[BOOKS] ([B_CONTRACT], [B_DATE], [B_MAN], [B_TITLE], [B_PRICE], [B_ADVANCE], [B_FEE], [B_PUBL], [B_CIRCUL], [B_EDIT], [B_REST]) VALUES (8, CAST(N'2005-10-01' AS Date), 3, N'Мертвые души                            ', CAST(1700.00 AS Decimal(6, 2)), CAST(600.00 AS Decimal(10, 2)), CAST(450.00 AS Decimal(8, 2)), CAST(N'2006-02-01' AS Date), 950, 5, 950)
GO
INSERT [dbo].[BOOKS] ([B_CONTRACT], [B_DATE], [B_MAN], [B_TITLE], [B_PRICE], [B_ADVANCE], [B_FEE], [B_PUBL], [B_CIRCUL], [B_EDIT], [B_REST]) VALUES (9, CAST(N'2007-06-18' AS Date), 7, N'Евгений Онегин                          ', CAST(1100.00 AS Decimal(6, 2)), CAST(300.00 AS Decimal(10, 2)), CAST(501.00 AS Decimal(8, 2)), CAST(N'2007-11-20' AS Date), 2500, 6, 2500)
GO
INSERT [dbo].[BOOKS] ([B_CONTRACT], [B_DATE], [B_MAN], [B_TITLE], [B_PRICE], [B_ADVANCE], [B_FEE], [B_PUBL], [B_CIRCUL], [B_EDIT], [B_REST]) VALUES (10, CAST(N'2008-05-03' AS Date), 8, N'Амулет добра                            ', CAST(500.00 AS Decimal(6, 2)), CAST(100.00 AS Decimal(10, 2)), CAST(110.00 AS Decimal(8, 2)), CAST(N'2008-10-15' AS Date), 3000, 7, 3000)
GO
SET IDENTITY_INSERT [dbo].[BOOKS] OFF
GO
SET IDENTITY_INSERT [dbo].[CUSTOMERS] ON 
GO
INSERT [dbo].[CUSTOMERS] ([C_ID], [C_NAME], [C_ADDR]) VALUES (1, N'Ефремов                       ', N'г. Уфа, ул. Кирова                                ')
GO
INSERT [dbo].[CUSTOMERS] ([C_ID], [C_NAME], [C_ADDR]) VALUES (3, N'Карпов                        ', N'г. Уфа, ул. Ленина                                ')
GO
INSERT [dbo].[CUSTOMERS] ([C_ID], [C_NAME], [C_ADDR]) VALUES (4, N'Литвинова                     ', N'г. Уфа, ул. Первомайская                          ')
GO
INSERT [dbo].[CUSTOMERS] ([C_ID], [C_NAME], [C_ADDR]) VALUES (5, N'Низаева                       ', N'г.Москва, ул. Пушкина                             ')
GO
INSERT [dbo].[CUSTOMERS] ([C_ID], [C_NAME], [C_ADDR]) VALUES (6, N'Воланд                        ', N'г. Москва, ул. Садовая                            ')
GO
INSERT [dbo].[CUSTOMERS] ([C_ID], [C_NAME], [C_ADDR]) VALUES (7, N'Коровьев                      ', N'г. Москва, ул. Победы                             ')
GO
INSERT [dbo].[CUSTOMERS] ([C_ID], [C_NAME], [C_ADDR]) VALUES (8, N'Магарита                      ', N'г. Москва, ул. Юбилейная                          ')
GO
INSERT [dbo].[CUSTOMERS] ([C_ID], [C_NAME], [C_ADDR]) VALUES (9, N'Бегемот                       ', N'г. Уфа, ул. Карла Маркса                          ')
GO
SET IDENTITY_INSERT [dbo].[CUSTOMERS] OFF
GO
INSERT [dbo].[EDITORS] ([B_ID], [E_ID]) VALUES (6, 3)
GO
INSERT [dbo].[EDITORS] ([B_ID], [E_ID]) VALUES (7, 3)
GO
INSERT [dbo].[EDITORS] ([B_ID], [E_ID]) VALUES (8, 5)
GO
INSERT [dbo].[EDITORS] ([B_ID], [E_ID]) VALUES (9, 8)
GO
INSERT [dbo].[EDITORS] ([B_ID], [E_ID]) VALUES (10, 3)
GO
SET IDENTITY_INSERT [dbo].[EMPLOYEES] ON 
GO
INSERT [dbo].[EMPLOYEES] ([E_ID], [E_FNAME], [E_LNAME], [E_BORN], [E_SEX], [E_POST], [E_ROOM], [E_TEL], [E_INN], [E_PASSP], [E_ORG], [E_PDATE], [E_ADDR]) VALUES (3, N'Бенгальский         ', N'Жорж                          ', CAST(N'1974-04-13' AS Date), 0, 2, 3, N'9578423654', N'124895137845', N'8457 595268 ', N'г. Москва, ул.                ', CAST(N'1988-04-05' AS Date), NULL)
GO
INSERT [dbo].[EMPLOYEES] ([E_ID], [E_FNAME], [E_LNAME], [E_BORN], [E_SEX], [E_POST], [E_ROOM], [E_TEL], [E_INN], [E_PASSP], [E_ORG], [E_PDATE], [E_ADDR]) VALUES (4, N'Босой               ', N'Никанор                       ', CAST(N'2001-01-30' AS Date), 0, 9, 3, N'9578423654', N'175846024846', N'4851 204526 ', N'г. Москва, ул.                ', CAST(N'2008-04-05' AS Date), NULL)
GO
INSERT [dbo].[EMPLOYEES] ([E_ID], [E_FNAME], [E_LNAME], [E_BORN], [E_SEX], [E_POST], [E_ROOM], [E_TEL], [E_INN], [E_PASSP], [E_ORG], [E_PDATE], [E_ADDR]) VALUES (5, N'Лиходеев            ', N'Степан                        ', CAST(N'1995-06-18' AS Date), 0, 1, 13, N'055487    ', N'843801642278', N'4851 829473 ', N'г. Уфа, ул.                   ', CAST(N'2010-12-03' AS Date), N'г. Казань, ул.                                    ')
GO
INSERT [dbo].[EMPLOYEES] ([E_ID], [E_FNAME], [E_LNAME], [E_BORN], [E_SEX], [E_POST], [E_ROOM], [E_TEL], [E_INN], [E_PASSP], [E_ORG], [E_PDATE], [E_ADDR]) VALUES (6, N'Семплеяров          ', N'Аркадий                       ', CAST(N'1955-08-14' AS Date), 0, 3, 10, N'20-50-74  ', N'170033481476', N'8941 589615 ', N'г. Уфа, ул.                   ', CAST(N'2013-09-13' AS Date), NULL)
GO
INSERT [dbo].[EMPLOYEES] ([E_ID], [E_FNAME], [E_LNAME], [E_BORN], [E_SEX], [E_POST], [E_ROOM], [E_TEL], [E_INN], [E_PASSP], [E_ORG], [E_PDATE], [E_ADDR]) VALUES (7, N'Соков               ', N'Андрей                        ', CAST(N'1995-07-09' AS Date), 0, 2, 3, N'9578423654', N'107958451511', N'1574 854612 ', N'г. Казань, ул.                ', CAST(N'2017-04-12' AS Date), N'г. Казань, ул.                                    ')
GO
INSERT [dbo].[EMPLOYEES] ([E_ID], [E_FNAME], [E_LNAME], [E_BORN], [E_SEX], [E_POST], [E_ROOM], [E_TEL], [E_INN], [E_PASSP], [E_ORG], [E_PDATE], [E_ADDR]) VALUES (8, N'Кадырова            ', N'Алсу                          ', CAST(N'2000-05-06' AS Date), 1, 1, 14, N'84-48-14  ', N'480277158940', N'8554 256792 ', N'г. Казань, ул.                ', CAST(N'2019-01-04' AS Date), N'г. Москва, ул.                                    ')
GO
INSERT [dbo].[EMPLOYEES] ([E_ID], [E_FNAME], [E_LNAME], [E_BORN], [E_SEX], [E_POST], [E_ROOM], [E_TEL], [E_INN], [E_PASSP], [E_ORG], [E_PDATE], [E_ADDR]) VALUES (9, N'Белозерская         ', N'Любовь                        ', CAST(N'1995-01-27' AS Date), 1, 2, NULL, NULL, N'148854720140', N'4712 001745 ', N'г. Москва, ул.                ', CAST(N'2018-01-30' AS Date), NULL)
GO
SET IDENTITY_INSERT [dbo].[EMPLOYEES] OFF
GO
INSERT [dbo].[ITEMS] ([O_ID], [B_ID], [B_COUNT]) VALUES (1, 6, 10)
GO
INSERT [dbo].[ITEMS] ([O_ID], [B_ID], [B_COUNT]) VALUES (2, 7, 15)
GO
INSERT [dbo].[ITEMS] ([O_ID], [B_ID], [B_COUNT]) VALUES (2, 9, 15)
GO
INSERT [dbo].[ITEMS] ([O_ID], [B_ID], [B_COUNT]) VALUES (1, 9, 10)
GO
INSERT [dbo].[ITEMS] ([O_ID], [B_ID], [B_COUNT]) VALUES (3, 8, 1)
GO
INSERT [dbo].[ITEMS] ([O_ID], [B_ID], [B_COUNT]) VALUES (3, 10, 10)
GO
INSERT [dbo].[ITEMS] ([O_ID], [B_ID], [B_COUNT]) VALUES (3, 6, 15)
GO
INSERT [dbo].[ITEMS] ([O_ID], [B_ID], [B_COUNT]) VALUES (4, 6, 7)
GO
INSERT [dbo].[ITEMS] ([O_ID], [B_ID], [B_COUNT]) VALUES (5, 8, 4)
GO
INSERT [dbo].[ITEMS] ([O_ID], [B_ID], [B_COUNT]) VALUES (6, 7, 5)
GO
INSERT [dbo].[ITEMS] ([O_ID], [B_ID], [B_COUNT]) VALUES (6, 10, 80)
GO
INSERT [dbo].[ITEMS] ([O_ID], [B_ID], [B_COUNT]) VALUES (7, 9, 50)
GO
INSERT [dbo].[ITEMS] ([O_ID], [B_ID], [B_COUNT]) VALUES (8, 6, 10)
GO
INSERT [dbo].[ITEMS] ([O_ID], [B_ID], [B_COUNT]) VALUES (9, 10, 1)
GO
INSERT [dbo].[ITEMS] ([O_ID], [B_ID], [B_COUNT]) VALUES (9, 8, 2)
GO
SET IDENTITY_INSERT [dbo].[ORDERS] ON 
GO
INSERT [dbo].[ORDERS] ([O_ID], [O_COMPANY], [O_DATE], [O_READY]) VALUES (1, 1, CAST(N'2018-01-25' AS Date), CAST(N'2018-03-15' AS Date))
GO
INSERT [dbo].[ORDERS] ([O_ID], [O_COMPANY], [O_DATE], [O_READY]) VALUES (2, 7, CAST(N'2018-02-14' AS Date), CAST(N'2018-03-02' AS Date))
GO
INSERT [dbo].[ORDERS] ([O_ID], [O_COMPANY], [O_DATE], [O_READY]) VALUES (3, 1, CAST(N'2018-06-15' AS Date), CAST(N'2018-07-15' AS Date))
GO
INSERT [dbo].[ORDERS] ([O_ID], [O_COMPANY], [O_DATE], [O_READY]) VALUES (4, 5, CAST(N'2019-04-15' AS Date), CAST(N'2019-05-10' AS Date))
GO
INSERT [dbo].[ORDERS] ([O_ID], [O_COMPANY], [O_DATE], [O_READY]) VALUES (5, 8, CAST(N'2019-04-20' AS Date), CAST(N'2019-06-15' AS Date))
GO
INSERT [dbo].[ORDERS] ([O_ID], [O_COMPANY], [O_DATE], [O_READY]) VALUES (6, 4, CAST(N'2020-12-15' AS Date), CAST(N'2021-01-30' AS Date))
GO
INSERT [dbo].[ORDERS] ([O_ID], [O_COMPANY], [O_DATE], [O_READY]) VALUES (7, 1, CAST(N'2021-04-08' AS Date), CAST(N'2021-04-30' AS Date))
GO
INSERT [dbo].[ORDERS] ([O_ID], [O_COMPANY], [O_DATE], [O_READY]) VALUES (8, 6, CAST(N'2017-12-14' AS Date), CAST(N'2018-01-20' AS Date))
GO
INSERT [dbo].[ORDERS] ([O_ID], [O_COMPANY], [O_DATE], [O_READY]) VALUES (9, 9, CAST(N'2019-08-14' AS Date), CAST(N'2019-09-01' AS Date))
GO
SET IDENTITY_INSERT [dbo].[ORDERS] OFF
GO
SET IDENTITY_INSERT [dbo].[POSTS] ON 
GO
INSERT [dbo].[POSTS] ([P_ID], [P_POST], [P_SAL]) VALUES (1, N'Редактор                      ', CAST(15000.00 AS Decimal(8, 2)))
GO
INSERT [dbo].[POSTS] ([P_ID], [P_POST], [P_SAL]) VALUES (2, N'Редактор                      ', CAST(20000.00 AS Decimal(8, 2)))
GO
INSERT [dbo].[POSTS] ([P_ID], [P_POST], [P_SAL]) VALUES (3, N'Программист                   ', CAST(50000.00 AS Decimal(8, 2)))
GO
INSERT [dbo].[POSTS] ([P_ID], [P_POST], [P_SAL]) VALUES (4, N'Главный редактор              ', CAST(150000.00 AS Decimal(8, 2)))
GO
INSERT [dbo].[POSTS] ([P_ID], [P_POST], [P_SAL]) VALUES (9, N'Стажер                        ', CAST(10000.00 AS Decimal(8, 2)))
GO
SET IDENTITY_INSERT [dbo].[POSTS] OFF
GO
INSERT [dbo].[ROOMS] ([R_NO], [R_TEL]) VALUES (3, N'9578423654')
GO
INSERT [dbo].[ROOMS] ([R_NO], [R_TEL]) VALUES (7, N'24-41-18  ')
GO
INSERT [dbo].[ROOMS] ([R_NO], [R_TEL]) VALUES (10, N'20-50-74  ')
GO
INSERT [dbo].[ROOMS] ([R_NO], [R_TEL]) VALUES (13, N'055487    ')
GO
INSERT [dbo].[ROOMS] ([R_NO], [R_TEL]) VALUES (14, N'84-48-14  ')
GO
SET IDENTITY_INSERT [dbo].[TITLES] ON 
GO
INSERT [dbo].[TITLES] ([B_ID], [A_ID], [A_NO], [A_FEE]) VALUES (6, 1, 1, CAST(100 AS Decimal(3, 0)))
GO
INSERT [dbo].[TITLES] ([B_ID], [A_ID], [A_NO], [A_FEE]) VALUES (7, 4, 1, CAST(100 AS Decimal(3, 0)))
GO
INSERT [dbo].[TITLES] ([B_ID], [A_ID], [A_NO], [A_FEE]) VALUES (9, 3, 1, CAST(100 AS Decimal(3, 0)))
GO
INSERT [dbo].[TITLES] ([B_ID], [A_ID], [A_NO], [A_FEE]) VALUES (10, 5, 1, CAST(84 AS Decimal(3, 0)))
GO
INSERT [dbo].[TITLES] ([B_ID], [A_ID], [A_NO], [A_FEE]) VALUES (8, 2, 1, CAST(100 AS Decimal(3, 0)))
GO
SET IDENTITY_INSERT [dbo].[TITLES] OFF
GO
ALTER TABLE [dbo].[BOOKS]  WITH CHECK ADD  CONSTRAINT [FK_BOOKS_EMPLOYEES] FOREIGN KEY([B_MAN])
REFERENCES [dbo].[EMPLOYEES] ([E_ID])
GO
ALTER TABLE [dbo].[BOOKS] CHECK CONSTRAINT [FK_BOOKS_EMPLOYEES]
GO
ALTER TABLE [dbo].[BOOKS]  WITH CHECK ADD  CONSTRAINT [FK_BOOKS_EMPLOYEES1] FOREIGN KEY([B_EDIT])
REFERENCES [dbo].[EMPLOYEES] ([E_ID])
GO
ALTER TABLE [dbo].[BOOKS] CHECK CONSTRAINT [FK_BOOKS_EMPLOYEES1]
GO
ALTER TABLE [dbo].[EDITORS]  WITH CHECK ADD  CONSTRAINT [FK_EDITORS_BOOKS] FOREIGN KEY([B_ID])
REFERENCES [dbo].[BOOKS] ([B_CONTRACT])
GO
ALTER TABLE [dbo].[EDITORS] CHECK CONSTRAINT [FK_EDITORS_BOOKS]
GO
ALTER TABLE [dbo].[EDITORS]  WITH CHECK ADD  CONSTRAINT [FK_EDITORS_EMPLOYEES] FOREIGN KEY([E_ID])
REFERENCES [dbo].[EMPLOYEES] ([E_ID])
GO
ALTER TABLE [dbo].[EDITORS] CHECK CONSTRAINT [FK_EDITORS_EMPLOYEES]
GO
ALTER TABLE [dbo].[EMPLOYEES]  WITH CHECK ADD  CONSTRAINT [FK_EMPLOYEES_POSTS] FOREIGN KEY([E_POST])
REFERENCES [dbo].[POSTS] ([P_ID])
ON UPDATE CASCADE
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[EMPLOYEES] CHECK CONSTRAINT [FK_EMPLOYEES_POSTS]
GO
ALTER TABLE [dbo].[EMPLOYEES]  WITH CHECK ADD  CONSTRAINT [FK_EMPLOYEES_ROOMS] FOREIGN KEY([E_ROOM], [E_TEL])
REFERENCES [dbo].[ROOMS] ([R_NO], [R_TEL])
ON UPDATE CASCADE
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[EMPLOYEES] CHECK CONSTRAINT [FK_EMPLOYEES_ROOMS]
GO
ALTER TABLE [dbo].[ITEMS]  WITH CHECK ADD  CONSTRAINT [FK_ITEMS_BOOKS] FOREIGN KEY([B_ID])
REFERENCES [dbo].[BOOKS] ([B_CONTRACT])
GO
ALTER TABLE [dbo].[ITEMS] CHECK CONSTRAINT [FK_ITEMS_BOOKS]
GO
ALTER TABLE [dbo].[ITEMS]  WITH CHECK ADD  CONSTRAINT [FK_ITEMS_ORDERS] FOREIGN KEY([O_ID])
REFERENCES [dbo].[ORDERS] ([O_ID])
GO
ALTER TABLE [dbo].[ITEMS] CHECK CONSTRAINT [FK_ITEMS_ORDERS]
GO
ALTER TABLE [dbo].[ORDERS]  WITH CHECK ADD FOREIGN KEY([O_COMPANY])
REFERENCES [dbo].[CUSTOMERS] ([C_ID])
GO
ALTER TABLE [dbo].[TITLES]  WITH CHECK ADD  CONSTRAINT [FK_TITLES_AUTHORS] FOREIGN KEY([A_ID])
REFERENCES [dbo].[AUTHORS] ([A_ID])
GO
ALTER TABLE [dbo].[TITLES] CHECK CONSTRAINT [FK_TITLES_AUTHORS]
GO
ALTER TABLE [dbo].[TITLES]  WITH CHECK ADD  CONSTRAINT [FK_TITLES_BOOKS] FOREIGN KEY([B_ID])
REFERENCES [dbo].[BOOKS] ([B_CONTRACT])
GO
ALTER TABLE [dbo].[TITLES] CHECK CONSTRAINT [FK_TITLES_BOOKS]
GO
